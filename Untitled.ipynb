# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
source('tests.R')
source('cleanup.R')
library(ggplot2)
library(cowplot)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.
#
# Warning message in file(filename, "r", encoding = encoding):
# “cannot open file 'tests.R': No such file or directory”
# Error in file(filename, "r", encoding = encoding): cannot open the connection
# Traceback:
#
# 1. source("tests.R")
# 2. file(filename, "r", encoding = encoding)

# %% [markdown]
# ### a different data set I found on the website
# I called it "vaccine"

# %%
vaccine <- read_csv("data/vaccination-administration-bydosenumber2.csv")
slice(vaccine, 1:6)
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 8013 Columns: 30
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (10): prename, prfname, product_name, numtotal_totaldoses_admin, numtot...
# dbl  (19): pruid, numdelta_dose1, numdelta_dose2, numdelta_dose3, numdelta_d...
# date  (1): week_end
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   week_end   pruid prename                   prfname
# 1 2020-12-19  1    Canada                    Canada
# 2 2020-12-19  1    Canada                    Canada
# 3 2020-12-19  1    Canada                    Canada
# 4 2020-12-19  1    Canada                    Canada
# 5 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
# 6 2020-12-19 10    Newfoundland and Labrador Terre-Neuve-et-Labrador
#   product_name                                        numtotal_totaldoses_admin
# 1 Not reported                                        0
# 2 Pfizer-BioNTech Comirnaty (ages 12 years and older) 12360
# 3 Total                                               12362
# 4 Unknown                                             2
# 5 Not reported                                        0
# 6 Pfizer-BioNTech Comirnaty (ages 12 years and older) 972
#   numtotal_dose1_admin numtotal_dose2_admin numtotal_dose3_admin
# 1 0                    0                    NA
# 2 7632                 0                    NA
# 3 7634                 0                    NA
# 4 2                    0                    NA
# 5 0                    0                    NA
# 6 972                  0                    NA
#   numtotal_dose4_admin ⋯ num2weekdelta_dose3 num2weekdelta_dose4
# 1 NA                   ⋯ NA                  NA
# 2 NA                   ⋯ NA                  NA
# 3 NA                   ⋯ NA                  NA
# 4 NA                   ⋯ NA                  NA
# 5 NA                   ⋯ NA                  NA
# 6 NA                   ⋯ NA                  NA
#   num2weekdelta_dose5+ num2weekdelta_notreported num4weekdelta_dose1
# 1 NA                   NA                        NA
# 2 NA                   NA                        NA
# 3 NA                   NA                        NA
# 4 NA                   NA                        NA
# 5 NA                   NA                        NA
# 6 NA                   NA                        NA
#   num4weekdelta_dose2 num4weekdelta_dose3 num4weekdelta_dose4
# 1 NA                  NA                  NA
# 2 NA                  NA                  NA
# 3 NA                  NA                  NA
# 4 NA                  NA                  NA
# 5 NA                  NA                  NA
# 6 NA                  NA                  NA
#   num4weekdelta_dose5+ num4weekdelta_notreported
# 1 NA                   NA
# 2 NA                   NA
# 3 NA                   NA
# 4 NA                   NA
# 5 NA                   NA
# 6 NA                   NA

# %%
#vaccine_ca <- vaccine|>
 #       filter(prename == "Canada")|>
  #      select(week_end:numtotal_dosenotreported_admin)|>
   # select(!pruid:product_name)|>
    #group_by(week_end)|>
    #summarise(new=rowSums(.))

#        mutate(numbers = numtotal_partially + numtotal_fully+ numtotal_additional+ numtotal_2nd_additional+ numtotal_recent_fullyoradditional)
#filter for all sexes

      #  group_by(week_end,age)
#vaccine_ca

#aaa <- vaccine_ca|>
#ggplot(aes(y=numtotal_additional, x=week_end, color=age))+
#geom_point()

#aaa

# %% [markdown]
# #### the dataset we wanted to work with called "data2"

# %%
data2 <- read_csv("data/vaccine_byAge.csv")
data2
# Out:
# Rows: 73584 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): prename, prfname, sex, age, numtotal_atleast1dose, numtotal_parti...
# dbl   (4): pruid, numtotal_additional, numtotal_2nd_additional, numtotal_rec...
# date  (1): week_end
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#       pruid prename prfname week_end   sex          age
# 1     1     Canada  Canada  2020-12-19 All sexes    0–15
# 2     1     Canada  Canada  2020-12-19 All sexes    16–69
# 3     1     Canada  Canada  2020-12-19 All sexes    70–74
# ⋮     ⋮     ⋮       ⋮       ⋮          ⋮            ⋮
# 73582 62    Nunavut Nunavut 2022-10-09 Not reported All ages
# 73583 62    Nunavut Nunavut 2022-10-09 Not reported Not reported
# 73584 62    Nunavut Nunavut 2022-10-09 Not reported Unknown
#       numtotal_atleast1dose numtotal_partially numtotal_fully
# 1     2                     2                  0
# 2     11766                 11766              0
# 3     174                   174                0
# ⋮     ⋮                     ⋮                  ⋮
# 73582 0                     0                  0.0
# 73583 0                     0                  0.0
# 73584 0                     0                  0.0
#       numtotal_additional numtotal_2nd_additional
# 1     NA                  NA
# 2     NA                  NA
# 3     NA                  NA
# ⋮     ⋮                   ⋮
# 73582 0                   0
# 73583 0                   0
# 73584 0                   0
#       numtotal_recent_fullyoradditional proptotal_atleast1dose
# 1     NA                                <0.1
# 2     NA                                0.1
# 3     NA                                <0.1
# ⋮     ⋮                                 ⋮
# 73582 NA                                na
# 73583 NA                                na
# 73584 NA                                na
#       proptotal_partially proptotal_fully proptotal_additional
# 1     <0.1                0               NA
# 2     0.1                 0               NA
# 3     <0.1                0               NA
# ⋮     ⋮                   ⋮               ⋮
# 73582 na                  na              na
# 73583 na                  na              na
# 73584 na                  na              na
#       proptotal_2nd_additional proptotal_recent_fullyoradditional
# 1     NA                       NA
# 2     NA                       NA
# 3     NA                       NA
# ⋮     ⋮                        ⋮
# 73582 na                       na
# 73583 na                       na
# 73584 na                       na

# %%
#vaccine_ca(is.na(vaccine_ca)) <- 0
#vaccine_ca <-       mutate(vaccine_ca, number = rowSums(numtotal_atleast1dose:numtotal_recent_fullyoradditional, na.rm = TRUE))
#vaccine_ca <- mutate(vaccine_ca, number = numtotal_atleast1dose+numtotal_partially+numtotal_fully +numtotal_additional+ numtotal_2nd_additional+numtotal_recent_fullyoradditional , na.rm=TRUE)
#df <- as.data.frame(vaccine_ca)
#mutate_all(df, ~colesce(.,0))
#vaccine_ca

# %%
library(RColorBrewer)
display.brewer.all(colorblindFriendly = TRUE)
# Out:
# plot without title

# %% [markdown]
# logistic fit

# %%
selected <- data2|>
filter(prename=="Canada")|>
select(week_end, age, numtotal_atleast1dose)
selected
# Out:
#      week_end   age          numtotal_atleast1dose
# 1    2020-12-19 0–15         2
# 2    2020-12-19 16–69        11766
# 3    2020-12-19 70–74        174
# ⋮    ⋮          ⋮            ⋮
# 5274 2022-10-09 All ages     0
# 5275 2022-10-09 Not reported 0
# 5276 2022-10-09 Unknown      0

# %% [markdown]
# some visualization of the data

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

graph1 <- ggplot(selected, aes(x=week_end, y=numtotal_atleast1dose, color=as_factor(age)))+
    geom_point()+
    facet_grid(rows = vars(age))+
    xlab("Date") +
    ylab("Number of New Vaccinations") +
    labs(color="Age Cathegory")+
    theme(text = element_text(size = 12))        

graph1
# Out:
# plot without title
